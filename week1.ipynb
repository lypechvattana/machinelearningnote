# %% [markdown]
# # Module 1: Supervised Machine Learning: Regression and Classification
# ## Module 1: Overview of Machine Learning

# %% [markdown]
# <b> What is machine learning? </b>: is a field of study that gives computers the ability to learn without being explicitly programmed, said Arthur Samuel (1959).
#
# Machine learning algorithms:
# - Supervised learning
# - Unsupervised learning
# - Recommender systems
# - Reinforcement learning
#
# ## 1. Supervised vs Unsupervised Learning
# ### Supervised Learning
# Common typpe of Supervised Learning (SVL) algorithm:
# - regression
# - classification
# #### Regression
# How it simply work: SVL learn to predict input, output or X to Y mapping. In SVL, we given both input and outpt during the planning and using regression to predict.
#
# ![image.png](attachment:image.png)
#
# #### Classification
#
# In Classification, the output class and output category are refering to the same thing which is the output.
#
# Classification can predict a class or a category (hence the term classify), and those category can be text or number 0,1 and 2.
#
# What differentiate classification from regression? Classification take only a small finite limited set of output category such as 0,1 and 2 but not decimal number in between like 0.5.
#
# ![image-2.png](attachment:image-2.png)
#
# In Classification, a boundary line (as shown in image above) is found to classify.
#
# ### Unsupervised learning
# Basically summed up the different in the image below:
#
# ![image-3.png](attachment:image-3.png)
#
# THe image above shown 2 different "clusters". Clustering algoorithm is one type of unsupervised learning algorithm.

# %% [markdown]
# ## 2. Regression Model
#
# Regression model is one of the most common algorithm of supevervised learning. According to Andrew, any model that output or predict number is considered as regression model.
